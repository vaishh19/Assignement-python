# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishh19/Assignement-python/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def remove_duplicates(s):
  result=""
  for char in s:
    if char not in result:
      result+=char
  return result

input_str="programming"
print(remove_duplicates(input_str))
# Out:
# progamin

# %%
def convert_minutes(minutes):
  hours=minutes//60
  mins=minutes%60
  if hours >0:
    if mins>0:
      return f"{hours} hr{'s' if hours > 1 else ''} {mins} minute{'s' if mins>1 else ''}"
    else:
      return f"{hours} hr {'s' if hours > 1 else ''}"
  else:
    return f"{mins} minute{'s'if mins > 1 else ''}"
print(convert_minutes(130))
print(convert_minutes(110))
# Out:
# 2 hrs 10 minutes
# 1 hr 50 minutes
